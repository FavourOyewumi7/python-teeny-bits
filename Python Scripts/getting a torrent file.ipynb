# %%
from bs4 import BeautifulSoup
import requests as re
import lxml

# %%
link = 'https://torrentgalaxy.to/torrents.php?parent_cat=&search=the+bachelor&sort=id&order=desc&page=1'

# %%
cont = re.get(link)

# %%
print(cont.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(cont.content, 'html.parser')
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>TGx:Search results for "the bachelor"</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="TorrentGalaxy 1.0" name="generator">
# <meta content="TorrentGalaxy https://torrentgalaxy.to http://galaxy2gchufcb3z.onion" name="description"/>
# <meta content="TorrentGalaxy torrent galaxy magnet movies tv" name="keywords"/>
# <!--Favicon-->
# <link href="/common/favicon/favicon.ico" rel="shortcut icon"/>
# <link href="/common/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/common/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/common/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# ...

# %%
links = soup.find_all('a', href = True, text = True)

# %%
links
# Out:
# [<a href="/vpn.php"><span style="font-weight:800;">VPN</span></a>,
#  <a href="/lobby.php">Lobby</a>,
#  <a href="/arcade">Arcade-hall</a>,
#  <a href="/forums.php">Forum</a>,
#  <a href="/torrents.php">Browse</a>,
#  <a href="/latest">Latest</a>,
#  <a href="/streams"><span style="font-weight:500;color:red;text-shadow: 0 0 3px #FF0000;animation: blinker 0.5s linear 2;">Now streaming</span></a>,
#  <a href="/onliners">Onliners</a>,
#  <a href="https://proxygalaxy.pw" target="_blank">https://proxygalaxy.pw</a>,
#  <a class="btn btn-danger btn-xs" href="/vpn.php" role="button" style="padding: 1px 15px;">more info</a>,
#  <a href="/torrents-hotpicks.php?cat=0">First Cam</a>,
#  <a href="/torrents-hotpicks.php?cat=1">New Movies</a>,
#  <a href="/torrents-hotpicks.php?cat=3">New TV</a>,
#  <a href="/torrents-hotpicks.php?cat=2">Classics</a>,
#  <a href="/torrents-hotpicks.php?cat=4">Misc</a>,
#  <a class="btn btn-default btn-sm" href="/torrents.php">All categories</a>,
# ...

# %%
linkss
yell = []

# %%
for link in links:
    contt = link['href']
    yell.append(contt)

# %%
yell[69]
# Out:
# '/torrent/14157327/The-Bachelorette-S16E02-WEB-h264-BAE-TGx-'

# %%
t = '/torrent/14157327/The-Bachelorette-S16E02-WEB-h264-BAE-TGx-'

tw = 'https://torrentgalaxy.to'

print(tw)
# Out:
# https://torrentgalaxy.to

# %%
new_yell = []

for i in range(69, 300,5):
   
   new_yell.append(tw + yell[i])

# %%
new_yell
# Out:
# ['https://torrentgalaxy.to/torrent/14157327/The-Bachelorette-S16E02-WEB-h264-BAE-TGx-',
#  'https://torrentgalaxy.to/torrent/14157047/The-Bachelorette-S16E02-720p-WEB-h264-KOGi-TGx-',
#  'https://torrentgalaxy.to/torrent/14150758/The-Bachelorette-S16E01-720p-AMZN-WEB-DL-DDP5-1-H-264-NTb-TGx-',
#  'https://torrentgalaxy.to/torrent/14148500/The-Bachelor-AU-S08E10-WEB-DL-AAC2-0-H-264--TGx-',
#  'https://torrentgalaxy.to/torrent/14148490/The-Bachelor-AU-S08E14-WEB-DL-AAC2-0-H-264--TGx-',
#  'https://torrentgalaxy.to/torrent/14148486/The-Bachelor-AU-S08E11-WEB-DL-AAC2-0-H-264--TGx-',
#  'https://torrentgalaxy.to/torrent/14148475/The-Bachelor-AU-S08E13-WEB-DL-AAC2-0-H-264--TGx-',
#  'https://torrentgalaxy.to/torrent/14148473/The-Bachelor-AU-S08E12-WEB-DL-AAC2-0-H-264--TGx-',
#  'https://torrentgalaxy.to/torrent/14148303/The-Bachelorette-S16E01-WEB-h264-BAE-TGx-',
#  'https://torrentgalaxy.to/torrent/14147249/The-Bachelorette-S16E01-720p-HULU-WEB-DL-DDP5-1-H-264-NTb-TGx-',
# ...

# %%
w=[]
for yel in new_yell:
    contt = re.get(yel)
    sup = BeautifulSoup(contt.content, 'html.parser')
    er = sup.find_all('a', class_= 'btn-success', href = True, limit=1)
    for e in er:
        w.append(e['href'])
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ...

# %%
w
# Out:
# ['https://watercache.nanobytes.org/get/473ead165b6d5dbb9bf22525b761258bfe99c9c2/The.Bachelorette.S16E02.WEB.h264-BAE%5BTGx%5D',
#  'https://watercache.nanobytes.org/get/cbcf4994827cca33e9de5aa9445f8537075862fb/The.Bachelorette.S16E02.720p.WEB.h264-KOGi%5BTGx%5D',
#  'https://watercache.nanobytes.org/get/e40ac41a14c953ca31ff3124532063ccaf594bec/The.Bachelorette.S16E01.720p.AMZN.WEB-DL.DDP5.1.H.264-NTb%5BTGx%5D',
#  'https://watercache.nanobytes.org/get/e30bd8990e7c4d40c7154165987d452c7c9315a9/The.Bachelor.AU.S08E10.WEB-DL.AAC2.0.H.264-%5BTGx%5D',
#  'https://watercache.nanobytes.org/get/ebc3ee84f39bf26fdfb5bbae2f1aa1c2d4216626/The.Bachelor.AU.S08E14.WEB-DL.AAC2.0.H.264-%5BTGx%5D',
#  'https://watercache.nanobytes.org/get/be9d93fba59b15d919c75d8ee7ed579649620e63/The.Bachelor.AU.S08E11.WEB-DL.AAC2.0.H.264-%5BTGx%5D',
#  'https://watercache.nanobytes.org/get/0a6f5760810e931354d3a14ecdfd8375f56b750c/The.Bachelor.AU.S08E13.WEB-DL.AAC2.0.H.264-%5BTGx%5D',
# ...

# %%
for w in w:
    e = re.get(w)
    filepath = w.split('/')[-1] + '.torrent'
    with open(filepath, 'wb') as f:
        f.write(e.content)

# %%
# Out:
# <Response [200]>
